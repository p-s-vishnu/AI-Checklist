# %% [markdown]
# # Mid Term

# %% [markdown]
# ## Section A (2 marks each question)

# %% [markdown]
# ### 1. Create a 7x7 array with random values using numpy.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# random values using uniform distribution
out = np.random.rand(7,7)
print(out,out.shape,sep='\n\n')
# Out:
# [[0.4798263  0.76556972 0.19875612 0.28179651 0.71664135 0.36902449
#   0.61441342]
#  [0.67562319 0.65758572 0.18175684 0.65559805 0.31550258 0.74861118
#   0.06267671]
#  [0.78798617 0.39261936 0.56163004 0.82356082 0.71553654 0.53400924
#   0.69815116]
#  [0.05477642 0.17401183 0.77524951 0.94406894 0.75442613 0.04244788
#   0.51614203]
#  [0.75379983 0.80685513 0.16126346 0.75178249 0.78792407 0.32368582
#   0.34995319]
#  [0.80111819 0.78813215 0.15195166 0.88903907 0.86887252 0.39971929
#   0.33741561]
#  [0.15265535 0.69948529 0.68904954 0.4911917  0.09311076 0.25096118
#   0.55194133]]
#
# (7, 7)

# %% [markdown]
# ### 2. Given an array with strings -
# ```python
# str_arr = np.array(['Python', 'Machine learning', 'Sql', 'Excel']).
# ```
# Use inbuilt numpy functions to print the array in upper and lower case

# %%
str_arr = np.array(['Python', 'Machine learning', 'Sql', 'Excel'])

print(np.char.lower(str_arr))
print(np.char.upper(str_arr))
# Out:
# ['python' 'machine learning' 'sql' 'excel']
# ['PYTHON' 'MACHINE LEARNING' 'SQL' 'EXCEL']

# %% [markdown]
# ### 3. Create a Dataframe using the following dictionary:
#
#  ```python
# dicts = ({"Subject":["Machine Learning","Python"],
#        	"Mid Exam":[150,80],
#        	"End Exam":[200,70]})
# ```

# %%
dicts = ({"Subject":["Machine Learning","Python"],
       "Mid Exam":[150,80],
       "End Exam":[200,70]})
pd.DataFrame(dicts)
# Out:
#             Subject  Mid Exam  End Exam
# 0  Machine Learning       150       200
# 1            Python        80        70

# %% [markdown]
# ### 4. Write code to reshape the ```array: np.array([2,3,6,3.4,6,3])``` into a 2X3 array. After reshaping please get the square of all the elements.

# %%
arr = np.array([2,3,6,3.4,6,3])

new_arr = arr.reshape(2,3)
print(new_arr);print()

print(new_arr * 2)
# Out:
# [[2.  3.  6. ]
#  [3.4 6.  3. ]]
#
# [[ 4.   6.  12. ]
#  [ 6.8 12.   6. ]]

# %% [markdown]
# ## Section B (3 marks each question)

# %%
from os import listdir
print(listdir())
# Out:
# ['.ipynb_checkpoints', 'NPV EXAMSET', 'NPV EXAMSET.zip', 'PsVishnu_Midexam.ipynb', 'PsVishnu_Midterm_npv.ipynb']

# %% [markdown]
# ### 5. Read the books.csv and ratings.csv dataset. Merge both the datsets using pandas on the BookId column.

# %%
pd.set_option("display.width",1000)
pd.set_option("display.max_columns", None)

# %%
df1 = pd.read_csv("./NPV EXAMSET/book.csv")
df2 = pd.read_csv('./NPV EXAMSET/Rating.csv')

print(df1)
print('\n\n')
print(df2)
# Out:
#        bookID                                              title                        authors language_code
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...     J.K. Rowling-Mary GrandPré           eng
# 1           2  Harry Potter and the Order of the Phoenix (Har...     J.K. Rowling-Mary GrandPré           eng
# 2           3  Harry Potter and the Sorcerer's Stone (Harry P...     J.K. Rowling-Mary GrandPré           eng
# 3           4  Harry Potter and the Chamber of Secrets (Harry...                   J.K. Rowling           eng
# 4           5  Harry Potter and the Prisoner of Azkaban (Harr...     J.K. Rowling-Mary GrandPré           eng
# ...       ...                                                ...                            ...           ...
# 13714   47699                                     M Is for Magic  Neil Gaiman-Teddy Kristiansen           eng
# 13715   47700                                       Black Orchid        Neil Gaiman-Dave McKean           eng
# 13716   47701                        InterWorld (InterWorld  #1)     Neil Gaiman-Michael Reaves         en-US
# 13717   47708                                The Faeries' Oracle    Brian Froud-Jessica Macbeth           eng
# 13718   47709                      The World of The Dark Crystal                    Brian Froud           eng
#
# [13719 rows x 4 columns]
#
#
#
#        bookID  average_rating  ratings_count
# 0           1            4.56        1944099
# 1           2            4.49        1996446
# 2           3            4.47        5629932
# 3           4            4.41           6267
# 4           5            4.55        2149872
# ...       ...             ...            ...
# 13714   47699            3.82          11317
# 13715   47700            3.72           8710
# 13716   47701            3.53          14334
# 13717   47708            4.43           1550
# 13718   47709            4.29           3572
#
# [13719 rows x 3 columns]

# %%
# Merged Dataframe
merged = pd.merge(df1,df2,on="bookID",suffixes=('_left','_right'),indicator=True)
print(merged.head())
# Out:
#    bookID                                              title                     authors language_code  average_rating  ratings_count _merge
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...  J.K. Rowling-Mary GrandPré           eng            4.56        1944099   both
# 1       2  Harry Potter and the Order of the Phoenix (Har...  J.K. Rowling-Mary GrandPré           eng            4.49        1996446   both
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...  J.K. Rowling-Mary GrandPré           eng            4.47        5629932   both
# 3       4  Harry Potter and the Chamber of Secrets (Harry...                J.K. Rowling           eng            4.41           6267   both
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...  J.K. Rowling-Mary GrandPré           eng            4.55        2149872   both

# %% [markdown]
# ### 6. Find out the number of authors in the dataset.

# %%
# total entries in author column
df1['authors'].shape
# Out:
# (13719,)

# %%
value_count = df1['authors'].value_counts()
value_count[:10]
# Out:
# Agatha Christie                69
# Stephen King                   66
# Orson Scott Card               48
# Rumiko Takahashi               46
# P.G. Wodehouse                 42
# Terry Brooks                   40
# Piers Anthony                  34
# Margaret Weis-Tracy Hickman    33
# Dan Simmons                    32
# J.R.R. Tolkien                 31
# Name: authors, dtype: int64

# %%
print("Number of authors in the dataset",len(value_count))
# Out:
# Number of authors in the dataset 7605

# %% [markdown]
# ### 7. Find the number of books written by each author.

# %%
# Number of books by each author
print(value_count)
# Out:
# Agatha Christie                               69
# Stephen King                                  66
# Orson Scott Card                              48
# Rumiko Takahashi                              46
# P.G. Wodehouse                                42
#                                               ..
# Architecture For Humanity-Cameron Sinclair     1
# Astrid Lindgren-Harald Wiberg                  1
# Robert Todd Carroll                            1
# Mary Daly                                      1
# Suza Scalora                                   1
# Name: authors, Length: 7605, dtype: int64

# %% [markdown]
# ### 8. Plot the results of the previous question as a bar chart.

# %% [markdown]
# **Note:** There are 7605 authors in the previous list therefore bar chart is not able to plot it.
#
# Hence only plotting the top 50 authors.

# %%
bar_count = df1['authors'].value_counts()
# print(len(bar_count))
bar_count[:50].plot(kind="bar",figsize=(12,9))
plt.show()

# %% [markdown]
# ### 9. Plot the distribution of the average ratings column.

# %%
sns.distplot(df2['average_rating'],bins=15,color="gold")
plt.title('Average rating of books')
plt.show()

# %% [markdown]
# ## Section C (7 marks)

# %% [markdown]
# ### 10. Use the merged dataset to plot the following:  (3 + 4 marks)
#
#     a) Generate boxplots for all the numerical variables in the dataset.
#     b) Generate pairplots for the same dataset and point out the variables having a high correlation.

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13719 entries, 0 to 13718
# Data columns (total 7 columns):
# bookID            13719 non-null int64
# title             13719 non-null object
# authors           13719 non-null object
# language_code     13719 non-null object
# average_rating    13719 non-null float64
# ratings_count     13719 non-null int64
# _merge            13719 non-null category
# dtypes: category(1), float64(1), int64(2), object(3)
# memory usage: 602.9+ KB

# %% [markdown]
# Numerical columns in the dataset are
# - bookID (Irrelevant column)
# - average_rating
# - ratings_count

# %%
def plot_box(col,title):
    merged.boxplot(column=col,figsize=(10,8))
    plt.title(title)
    plt.show()

# %% [markdown]
# ### a) Boxplots

# %% [markdown]
# #### 1. Average rating

# %%
plot_box("average_rating","Average ratings")

# %% [markdown]
# #### 2. Ratings count

# %%
plot_box("ratings_count","Ratings count")

# %% [markdown]
# ### b) Pairplots

# %%
# Removing Book Id from the data frame because correlation with the column is not relevant
# Also removing the _merge which was created as part of the merge

# %%
df_pair = merged.loc[:,"title" : "ratings_count"]
df_pair.columns
# Out:
# Index(['title', 'authors', 'language_code', 'average_rating', 'ratings_count'], dtype='object')

# %%
sns.set()
sns.pairplot(df_pair,height=5)
plt.show()

# %% [markdown]
# We can see that, for pairplot, the columns under consideration are `average_rating` and `rating_count`.
#
# As the `average_rating` increases `ratings_count` is not showing any linear changes (neither positive nor negative), hence we can conclude that these columns dont follow any correlation.
#
# This can be confirmed by looking at the correlation matrix of the same.

# %%
df_pair.corr()
# Out:
#                 average_rating  ratings_count
# average_rating        1.000000       0.041206
# ratings_count         0.041206       1.000000
