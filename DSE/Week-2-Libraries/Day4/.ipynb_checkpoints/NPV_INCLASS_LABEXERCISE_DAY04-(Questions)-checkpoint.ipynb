# %% [markdown]
# # IN CLASS LAB EXERCISE - 04

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# **Data Description:-**
#
# **Survival**
# 0 = No, 1 = Yes
#
# **pclass**
# Ticket class
# 1 = 1st, 2 = 2nd, 3 = 3rd
#
# **sex**
# Sex
#
# **Age**
# Age in years
#
# **sibsp**
# siblings / spouses aboard the Titanic
#
# **parch**
# parents / children aboard the Titanic
#
# **ticket**
# Ticket number
#
# **fare**
# Passenger fare
#
# **cabin**
# Cabin number
#
# **embarked**
# Port of Embarkation
# C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# ----

# %%
pd.set_option("display.width",1000)
pd.set_option("display.max_columns",None)

# %%
embark = {'C':"Cherbourg",
         "Q":"Queenstown",
         "S":"Southampton"}

# %% [markdown]
# **Q.no (1) . Write a code to load 'train.csv' as data1 & 'test.csv' as data2.**

# %%
data1 = pd.read_csv('./data/train.csv')
data1.head()
# Out:
#    PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0            1         0       3                            Braund, Mr. Owen Harris    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1            2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2            3         1       3                             Heikkinen, Miss. Laina  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3            4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0            113803  53.1000  C123        S
# 4            5         0       3                           Allen, Mr. William Henry    male  35.0      0      0            373450   8.0500   NaN        S

# %%
data2 = pd.read_csv('./data/test.csv')

# %% [markdown]
# ---------

# %% [markdown]
# **Q.no (2) . Write a code to `concanate` data1 & data2 assign it as  `data_01`.**

# %%
data_01 = pd.concat((data1,data2),sort=False)
data_01
# Out:
#      PassengerId  Survived  Pclass                                               Name     Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0              1       0.0       3                            Braund, Mr. Owen Harris    male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1              2       1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1      0            PC 17599   71.2833   C85        C
# 2              3       1.0       3                             Heikkinen, Miss. Laina  female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3              4       1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0              113803   53.1000  C123        S
# 4              5       0.0       3                           Allen, Mr. William Henry    male  35.0      0      0              373450    8.0500   NaN        S
# ..           ...       ...     ...                                                ...     ...   ...    ...    ...                 ...       ...   ...      ...
# 413         1305       NaN       3                                 Spector, Mr. Woolf    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414         1306       NaN       1                       Oliva y Ocana, Dona. Fermina  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415         1307       NaN       3                       Saether, Mr. Simon Sivertsen    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416         1308       NaN       3                                Ware, Mr. Frederick    male   NaN      0      0              359309    8.0500   NaN        S
# 417         1309       NaN       3                           Peter, Master. Michael J    male   NaN      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(3). Write a code to show the `count of male and female` in ship using `bar plot` where color is `green`.[USE MATPLOTLIB]**

# %%
fm_count = data1['Sex'].value_counts()
print(fm_count)
# fm_count.index
plt.bar(x=['Male','Female'],height=fm_count,color='green',alpha=0.9)
plt.show()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(4). Write a code to show the age distribution of passengers in a ship using histogram plot for titanic dataset where `title - 'histogram for age distribution'`, `color is blue`, `bin size is 20`.[USE MATPLOTLIB]**

# %%
plt.hist(data1['Age'],bins=20,color='blue')
plt.title("Histogram for age distribution")
plt.show()
# Out:
# c:\users\p s v\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\p s v\appdata\local\programs\python\python37-32\lib\site-packages\numpy\lib\histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# --------

# %% [markdown]
# **Q.no(5). Write a code to plot a boxplot on a `Fare` column for titanic dataset.[USE MATPLOTLIB]**

# %%
data1.boxplot('Fare')
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(6). Write a code to plot a scatterplot where x-axis = `Pclass`,y-axis = `Fare` for titanic dataset.[USE MATPLOTLIB]**

# %%
data1.plot.scatter(x='Pclass',y='Fare')
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(7) .Write a code to plot boxplot on `x-axis = title`,`y-axis = age` for titanic dataset.[USE MATPLOTLIB]**

# %%
data1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype='object')

# %%
data1['title'] = data1['Name'].map(lambda x: x[x.index(',')+1:x.index('.')].strip())
titles = pd.unique(data1['title'])
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
# plt.subplots(figsize=(12,9))
data1.boxplot(column='Age',by="title",figsize=(12,9))
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(9). Write a code to show a `kde plot` for `'Age'` column for titanic dataset where `title = 'density plot` for `'age'` and `color is red`.[USE MATPLOTLIB]**

# %%
data1['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
#          ..
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64

# %%
data1['Age'].plot.kde(color="red")
plt.title('density plot')
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(10).Write a code to show `Areaplot` for `Age` column and then `sort index` for titanic dataset.[USE MATPLOTLIB]**

# %%
print(data1['Age'].value_counts().sort_index())
data1['Age'].value_counts().sort_index().plot.area()
plt.show()
# Out:
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    2
# 70.50    1
# 71.00    2
# 74.00    1
# 80.00    1
# Name: Age, Length: 88, dtype: int64

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(11). Write a code to show the `pie plot` for a given data below and show pie plot color in `yellow`,`red`,`blue` and use `shadow`,`explode`,`autopct`.**
#
# **foot_ball = 'Penalties', 'Field Goals', 'Free Kicks'**
#
# **goal = [24,58,11].    [USE MATPLOTLIB]**

# %%
foot_ball = ['Penalties','Field Goals','Free Kicks']
goal = [24,58,11]
fb = {k:v for k,v in zip(foot_ball,goal)}

df = pd.Series(fb)
colors = ['yellow', 'red', 'blue']
explode = [0., 0., 0.5]

df.plot.pie(explode=explode,autopct="%.2f",shadow=True)
plt.ylabel('Football')
plt.show()

# %% [markdown]
# -------

# %%
import seaborn as sns

# %% [markdown]
# **Q.no(12). Write a code to show a `heatmap` that represents the `Correlation` between the columns for titanic dataset.[Use `Seaborn`]**

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(data1.corr())
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# # Data Description

# %% [markdown]
# 1. symboling: -3, -2, -1, 0, 1, 2, 3.
# 2. normalized-losses: continuous from 65 to 256.
# 3. make:
# alfa-romero, audi, bmw, chevrolet, dodge, honda,
# isuzu, jaguar, mazda, mercedes-benz, mercury,
# mitsubishi, nissan, peugot, plymouth, porsche,
# renault, saab, subaru, toyota, volkswagen, volvo
#
# 4. fuel-type: diesel, gas.
# 5. aspiration: std, turbo.
# 6. num-of-doors: four, two.
# 7. body-style: hardtop, wagon, sedan, hatchback, convertible.
# 8. drive-wheels: 4wd, fwd, rwd.
# 9. engine-location: front, rear.
# 10. wheel-base: continuous from 86.6 120.9.
# 11. length: continuous from 141.1 to 208.1.
# 12. width: continuous from 60.3 to 72.3.
# 13. height: continuous from 47.8 to 59.8.
# 14. curb-weight: continuous from 1488 to 4066.
# 15. engine-type: dohc, dohcv, l, ohc, ohcf, ohcv, rotor.
# 16. num-of-cylinders: eight, five, four, six, three, twelve, two.
# 17. engine-size: continuous from 61 to 326.
# 18. fuel-system: 1bbl, 2bbl, 4bbl, idi, mfi, mpfi, spdi, spfi.
# 19. bore: continuous from 2.54 to 3.94.
# 20. stroke: continuous from 2.07 to 4.17.
# 21. compression-ratio: continuous from 7 to 23.
# 22. horsepower: continuous from 48 to 288.
# 23. peak-rpm: continuous from 4150 to 6600.
# 24. city-mpg: continuous from 13 to 49.
# 25. highway-mpg: continuous from 16 to 54.
# 26. price: continuous from 5118 to 45400.

# %% [markdown]
# **Load the automobile dataset.**

# %%
# dfa = pd.read_csv('./data/Automobile.csv',index_col=0)
dfa = pd.read_csv('./data/Automobile.csv')
dfa.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration number_of_doors   body_style drive_wheels engine_location  wheel_base  length  width  height  curb_weight engine_type number_of_cylinders  engine_size fuel_system  bore  stroke  compression_ratio  horsepower  peak_rpm  city_mpg  highway_mpg  price
# 0          3                168  alfa-romero       gas        std             two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc                four          130        mpfi  3.47    2.68                9.0         111      5000        21           27  13495
# 1          3                168  alfa-romero       gas        std             two  convertible          rwd           front        88.6   168.8   64.1    48.8         2548        dohc                four          130        mpfi  3.47    2.68                9.0         111      5000        21           27  16500
# 2          1                168  alfa-romero       gas        std             two    hatchback          rwd           front        94.5   171.2   65.5    52.4         2823        ohcv                 six          152        mpfi  2.68    3.47                9.0         154      5000        19           26  16500
# 3          2                164         audi       gas        std            four        sedan          fwd           front        99.8   176.6   66.2    54.3         2337         ohc                four          109        mpfi  3.19    3.40               10.0         102      5500        24           30  13950
# 4          2                164         audi       gas        std            four        sedan          4wd           front        99.4   176.6   66.4    54.3         2824         ohc                five          136        mpfi  3.19    3.40                8.0         115      5500        18           22  17450

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(13). Write a code to show the `boxplot` for `price` column for `automobile dataset`.[Use `Seaborn`].**

# %%
sns.boxplot(data=dfa,y="price")
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(14). Write a code to show the `distplot` on `price` column for  `automobile dataset`.[using seaborn]**

# %%
sns.set()
plt.subplots(figsize=(10,8))
sns.distplot(dfa['price'],bins=10,kde=True)
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(15). Write a code to show the `distplot` on `price` column for  `automobile dataset` `excluding kdeplot`.[using seaborn]**

# %%
sns.distplot(dfa['price'],kde=False)
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(16). Write a code to show the `distplot` on `price` column for  `automobile dataset` `including 'rug'` and shade.[using seaborn]**

# %%
sns.distplot(dfa['price'],rug=True,kde=False)
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(17). Write a code to show the `regressionplot` on `x-axis='city_mpg'`,`y-axis='highway_mpg'` for  `automobile dataset` `including 'marker'` and color was `red`.[using seaborn]**

# %%
sns.regplot(data=dfa,x='city_mpg',y='highway_mpg',marker="v",color="red")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# **Q.no(18). Write a code to show the `lmplot` on `x-axis='city_mpg'`,`y-axis='highway_mpg'` for  `automobile dataset` `including 'marker'` and color was `red`.[using seaborn]**

# %%
sns.lmplot(data=dfa,x="city_mpg",y="highway_mpg",markers="o",scatter_kws={'color':"red"})
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(19). Write a code to show the `lmplot` on `x-axis='price'`,`y-axis='horsepower'` for  `automobile dataset` including `col='engine_type'`.[using seaborn]**

# %%
sns.lmplot(data=dfa,x="price",y="horsepower",col="engine_type")
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(20). Write a code to show `distplot` on `'stroke'` column for `automobile` dataset where `bin size '20'`, `kde is true`.**

# %%
sns.distplot(dfa['stroke'],bins=20,kde=True)
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(21). Write a code to show `swarmplot` on `x-axis-'engine_type'` and  `y-axis-'price'` for `automobile` dataset.**

# %%
sns.swarmplot(data=dfa,x='engine_type',y="price")
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(22). Write a code to show `swarmplot` on `x-axis-'engine_type'` and  `y-axis-'stroke'` for `automobile` dataset` and
#       `jitter is true`.**

# %%
sns.swarmplot(data=dfa,x="engine_type",y="stroke",linewidth=1)
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(23). Write a code to show `boxplot` on `x-axis-'fuel_type'` and  `y-axis-'price'` for `automobile` dataset`.[use seaborn]**

# %%
sns.boxplot(data=dfa,x="fuel_type",y="price")
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(24). Write a code to show `boxplot` on `x-axis-'number_of_cylinders'` and  `y-axis-'price'` for `automobile` dataset`.[use seaborn]**

# %%
dfa.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration', 'number_of_doors', 'body_style', 'drive_wheels', 'engine_location', 'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type', 'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke', 'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price'], dtype='object')

# %%
sns.boxplot(data=dfa,x='number_of_cylinders',y="price")
plt.show()

# %% [markdown]
# ----

# %% [markdown]
# **Q.no(25). Write a code to show `violinplot` on `x-axis-'fuel_type'` and  `y-axis-'horsepower'` for `automobile` dataset` where `palette is 'husl'`.[use seaborn]**

# %%
sns.violinplot(x='fuel_type',y="horsepower",data=dfa,palette="husl")
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(26). Write a code to show `jointplot` on `x-axis-'price'` and  `y-axis-'horsepower'` for `automobile` dataset` where `kind is 'hex'`.   [use seaborn]**

# %%
sns.jointplot(data=dfa,x="price",y="horsepower",kind="hex")
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# **Q.no(27). Write a code to show `pointplot` on `x-axis-'number_of_cylinders'` and  `y-axis-'horsepower'` for `automobile` dataset` where `capsize is '.1'and `hue - 'fuel_type'`.[use seaborn]**

# %%
sns.pointplot(data=dfa,x="number_of_cylinders",y="horsepower",capsize=0.1,hue="fuel_type")
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# **Q.no(28). Write a code to show `pairplot` on `automobile` dataset.[use seaborn]**

# %%
sns.pairplot(data=dfa)
plt.show()

# %% [markdown]
# ------

# %% [markdown]
# # ------------------------------------- HAPPY LEARNING  -------------------------------------

# %% [markdown]
# ----
