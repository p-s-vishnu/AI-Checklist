# %% [markdown]
# <h1><center>Day 8</center></h1>

# %% [markdown]
# # Visualizations

# %%
import pandas as Pd

score = [10, 15, 20, 25]

Pd.Series(data=score)
# Out:
# 0    10
# 1    15
# 2    20
# 3    25
# dtype: int64

# %%
from os import listdir

print(listdir())
# Out:
# ['.ipynb_checkpoints', 'data', 'Day8.ipynb', 'myplot.png', 'NPV_INCLASS_LABEXERCISE_DAY04-(Questions).ipynb', 'NPV_TAKEHOME_LABEXERCISE_DAY04-(Questions).ipynb']

# %% [markdown]
# ### Line Plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x1 = np.array(range(2,9,2))
y1 = x1**2
y1
# Out:
# array([ 4, 16, 36, 64], dtype=int32)

# %%
x2 = x1
y2 = x2 ** 3
y2
# Out:
# array([  8,  64, 216, 512], dtype=int32)

# %%
plt.plot(x1,y1, linestyle="solid",label="plot1",marker="o",color="r")
plt.plot(x2,y2,linestyle="dotted",label="plot2",marker="v",color="g")

plt.ylabel("Y-Axis")
plt.xlabel("X-Axis")

# Custom a and y indexes 
plt.xticks([2,4,6,8,10])
# plt.yticks([12,24,36,48,90])

plt.title("First Plot")
plt.legend(fontsize=18,loc=0)
plt.savefig("myplot.png")
plt.show()
print()

# %% [markdown]
# ### Scatter Plot

# %%
x1,y1

plt.scatter(x1,y1,label="scatter points",marker="*",color="b")
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
stock_names = ["GOOG", "APPL", "IBM", "INTC", "CSCO"]
stock_value = [1000,800,200,400,800]

x_pos = range(len(stock_names))

plt.bar(x_pos,stock_value,width=0.35, label="ticker",align="center",color="b",alpha=0.3)
plt.xticks(x_pos, stock_names)
plt.xlabel("Companies")
plt.ylabel("Price")
plt.title("Current stock values")
plt.legend()
plt.show()

# %% [markdown]
# ## Using Visualization Libraries

# %% [markdown]
# ### House price analysis

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('./data/small_house_train.csv')

# %%
print(df.head())
# Out:
#    Id  LotFrontage  LotArea BldgType  OverallQual  YearBuilt  MasVnrArea  \
# 0   1         65.0     8450     1Fam            7       2003       196.0
# 1   2         80.0     9600     1Fam            6       1976         0.0
# 2   3         68.0    11250     1Fam            7       2001       162.0
# 3   4         60.0     9550     1Fam            7       1915         0.0
# 4   5         84.0    14260     1Fam            8       2000       350.0
#
#    TotalBsmtSF  1stFlrSF  GrLivArea  FullBath  Fireplaces FireplaceQu  \
# 0          856       856       1710         2           0         NaN
# 1         1262      1262       1262         2           1          TA
# 2          920       920       1786         2           1          TA
# 3          756       961       1717         1           1          Gd
# 4         1145      1145       2198         2           1          TA
#
#    GarageCars  YrSold SaleCondition  SalePrice
# 0           2    2008        Normal     208500
# ...

# %%
df.shape
# Out:
# (1460, 17)

# %%
sc = df['SaleCondition'].value_counts()
# type(sc)

sc.plot(kind='bar',label="count",color='r',alpha=0.5)
plt.title('Sales of various house types')
plt.legend()
plt.show()

# %%
sc1 = df[['SaleCondition','BldgType']].apply(pd.value_counts)
print(sc1)
# Out:
#          SaleCondition  BldgType
# 1Fam               NaN    1220.0
# 2fmCon             NaN      31.0
# Abnorml          101.0       NaN
# AdjLand            4.0       NaN
# Alloca            12.0       NaN
# Duplex             NaN      52.0
# Family            20.0       NaN
# Normal          1198.0       NaN
# Partial          125.0       NaN
# Twnhs              NaN      43.0
# TwnhsE             NaN     114.0

# %%
sc1.plot(kind="bar",color="rg",alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# - Magnitude based entity

# %% [markdown]
# ### Pie Chart

# %%
explode_list = list_zeros = [0] * 5 # len(vc)

explode_list[2] = 0.5

print(list_zeros)
# Out:
# [0, 0, 0.5, 0, 0]

# %%
vc = df['BldgType'].value_counts()
vc.plot(kind="pie")
plt.show()

# %%
vc.plot(kind="pie",explode=explode_list,autopct="%1.1f")
plt.title("Type of Buildings")
plt.ylabel("Still good")
# plt.legend()
plt.show()

# %% [markdown]
# ### Histogram

# %%
bins = 15
sales_price = df['SalePrice']
# sales_price.plot(kind="hist")
plt.hist(sales_price,bins=bins,color='r',alpha=0.5)
plt.show()

# %% [markdown]
# - e.g: Populations v/s Age charts

# %% [markdown]
# ### Box Plot

# %% [markdown]
# > When to use box plots?

# %%
values = list(range(101,201))
values.append(10)
values.append(300)

print(pd.DataFrame(values).describe())
box_plot_data = values
plt.boxplot(box_plot_data)
plt.show()
# Out:
#                 0
# count  102.000000
# mean   150.588235
# std     35.238186
# min     10.000000
# 25%    125.250000
# 50%    150.500000
# 75%    175.750000
# max    300.000000

# %%
plt.boxplot(df['SalePrice'],vert=False,whis=1.5)
plt.show()

# %%
df.boxplot('SalePrice','SaleCondition')
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
df.plot.scatter(x='YearBuilt',y='SalePrice');

# %%
df.plot.scatter(x="YrSold",y='SalePrice');

# %% [markdown]
# **Observations**
# -

# %% [markdown]
# ### Density Plot

# %% [markdown]
# - This is not affected by the number of columns

# %%
df['SalePrice'].plot(kind="kde")
plt.show()

# %%
df.plot.density()

# %% [markdown]
# ### Area Plot

# %%
df['YearBuilt'].value_counts().sort_index().plot.area();

# %%
df['YearBuilt'].value_counts().plot.area();

# %% [markdown]
# **Exercise**
# - Visualize GST Fine
# - Visualize Tax

# %% [markdown]
# ## Seaborn

# %% [markdown]
# ### Box plot

# %%
import seaborn as sns

# %%
sns.boxplot(data=df['SalePrice'])
plt.show()

# %% [markdown]
# ### Heat Map

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12,9))
# sns.heatmap(corrmat,square=True,vmax=0.8)
sns.heatmap(corrmat)
plt.show()

# %% [markdown]
# ### Distribution Plot (Histogram + Kernel Density Estimate point)

# %%
sns.distplot(df['SalePrice'],bins=10,kde=True);

# %% [markdown]
# ### Rug plot

# %%
f, ax = plt.subplots(figsize=(12,9))
sns.distplot(df['SalePrice'],bins=50,kde=False,rug=True);

# %% [markdown]
# ### Pair plot

# %%
sns.set()
cols = ['SalePrice','OverallQual','GrLivArea','GarageCars','TotalBsmtSF','FullBath']
sns.pairplot(df[cols],size=3)
plt.show()

# %% [markdown]
# ### Regression Plot

# %% [markdown]
# - Trend line
# -

# %%
sns.regplot(data=df,
           x='YearBuilt',
           y="SalePrice",
           )
plt.show()

# %% [markdown]
# ### LM PLot

# %%
sns.lmplot(x='YearBuilt',y='SalePrice',data=df)
plt.show()

# %% [markdown]
# ### Strip plot (Scatter plot family)

# %%
# sns.stripplot(data=df,x='YearBuilt',y="SalePrice",jitter=True)
# f, ax = plt.subplots(figsize=(12,9))
fig, axis = plt.subplots(figsize=(12,9))
sns.set(style="whitegrid")
sns.stripplot(data=df,x='SaleCondition',y="SalePrice",jitter=True)
plt.show()

# %% [markdown]
# ### Swarm Plot

# %%
help(sns.axes_style)
# Out:
# Help on function axes_style in module seaborn.rcmod:
#
# axes_style(style=None, rc=None)
#     Return a parameter dict for the aesthetic style of the plots.
#
#     This affects things like the color of the axes, whether a grid is
#     enabled by default, and other aesthetic elements.
#
#     This function returns an object that can be used in a ``with`` statement
#     to temporarily change the style parameters.
#
#     Parameters
#     ----------
#     style : dict, None, or one of {darkgrid, whitegrid, dark, white, ticks}
#         A dictionary of parameters or the name of a preconfigured set.
#     rc : dict, optional
#         Parameter mappings to override the values in the preset seaborn
#         style dictionaries. This only updates parameters that are
#         considered part of the style definition.
#
#     Examples
#     --------
#     >>> st = axes_style("whitegrid")
#
#     >>> set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
#
# ...

# %%
fig, axis = plt.subplots(figsize=(12,9))
# {darkgrid, whitegrid, dark, white, ticks}
sns.set()
sns.swarmplot(x="SaleCondition",y="SalePrice",data=df)
print(plt.show())
# Out:
# None

# %%
df['SalePriceSF'] = df['SalePrice']/df['GrLivArea']
fig, ax = plt.subplots(figsize=(10,8))
plt.hist(df['SalePriceSF'],bins=15,color="gold")
plt.title("Sale price per square foot")
plt.xlabel("Price per spuare feet")
plt.ylabel("Number of Sales")
plt.show()

# %% [markdown]
# ### Joint Plot ( Histogram and Scatter plot)

# %%
sns.jointplot(df['LotFrontage'],df['LotArea'],color='grey',label="lot area per frontage")
plt.legend()
plt.xlabel('Lot Frontage')
plt.ylabel('Lot Area')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Factorplot

# %%
sns.factorplot("Fireplaces","SalePrice",data=df);

# %% [markdown]
# ### Point Plot

# %%
sns.pointplot(x="Fireplaces",y="SalePrice",data=df,hue='FireplaceQu')
plt.show()
plt.clf()
