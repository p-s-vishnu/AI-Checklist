# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Python

# %%
"""
The most important shortcut ctrl + shift + P
"""
# Out:
# '\nThe most important shortcut ctrl + shift + P\n'

# %%
> Write a pascal triangle ?

# %% [markdown]
# ### The below cell is a markdown cell

# %% [markdown]
# Motivation is the reason for people's actions, willingness and goals. Motivation is derived from the word motive which is defined as a need that requires satisfaction. These needs could be wants or desires that are acquired through influence of culture, society, lifestyle, etc. or generally innate. Motivation is one's direction to behaviour, or what causes a person to want to repeat a behaviour, a set of force that acts behind the motives. An individual's motivation may be inspired by others or events (extrinsic motivation)[1] or it may come from within the individual (intrinsic motivation).[2] Motivation has been considered as one of the most important reasons that inspires a person to move forward in life.[3] Motivation results from the interaction of both conscious and unconscious factors. Mastering motivation to allow sustained and deliberate practice is central to high levels of achievement e.g. in the worlds of elite sport, medicine or music.[4]

# %% [markdown]
# ### The below is RawNBConvert

# %% [raw]
# Motivation is the reason for people's actions, willingness and goals. Motivation is derived from the word motive which is defined as a need that requires satisfaction. These needs could be wants or desires that are acquired through influence of culture, society, lifestyle, etc. or generally innate. Motivation is one's direction to behaviour, or what causes a person to want to repeat a behaviour, a set of force that acts behind the motives. An individual's motivation may be inspired by others or events (extrinsic motivation)[1] or it may come from within the individual (intrinsic motivation).[2] Motivation has been considered as one of the most important reasons that inspires a person to move forward in life.[3] Motivation results from the interaction of both conscious and unconscious factors. Mastering motivation to allow sustained and deliberate practice is central to high levels of achievement e.g. in the worlds of elite sport, medicine or music.[4]

# %% [markdown]
# > When to use the RawNB?

# %% [markdown]
# ## Types of Comments

# %% [markdown]
# Single comment

# %%
# This is it

# %% [markdown]
# Multiline comment

# %%
# jhdfkshd
# sjhdksejhdf
# hkhfsjd

# %% [markdown]
# Block comment

# %%
"""
This will give an output on your screen
"""
# print("Wont work if any code is here")
# Out:
# '\nThis will give an output on your screen\n'

# %% [markdown]
# > Why block comments are being displayed on the screen?

# %% [markdown]
# ## Let us print something

# %%
print("Testing quote skil'ls")
# Out:
# Testing quote skil'ls

# %%
print("If you' want \" both then use escape sequence")
# Out:
# If you' want " both then use escape sequence

# %%
print("""
This can be used to do multiline print

HEllo
""")
# Out:
# This can be used to do multiline print
#
# HEllo

# %%
print("\tThis is a tab")
# Out:
# 	This is a tab

# %% [markdown]
# ## Datatypes

# %% [markdown]
# String, int, float, boolean, complex

# %%
# Cut cells by using ctrl + shift + -
# Merge cells using shift + m

# %%
name = input("Enter your name\t")

print(name)
# Out:
# Enter your name	TRy
# TRy

# %%
# Multiline variable assignment
desc = "THis \
is not going to \
end here"
desc
# Out:
# 'THis is not going to end here'

# %% [markdown]
# **Employee form**

# %%
# ctrl + ] for indentation

# %%
def get_input(msg):
    return input(msg + "\t")

# %%
def display_name_type(var):
    
    print(var, type(var))

# %% [markdown]
# > how to have tab in JNB ?

# %%
name = get_input("*"*2 + "Enter employee details" + "*"*2+"\nName")
# emp_id = get_input("Enter id")
# emp_dept = get_input("Department")
# emp_email = get_input("Email")
# emp_contact = get_input("Contact")
# emp_age = get_input("Age")
# emp_height = get_input("Height")
# emp_weight = get_input("wt")
# Out:
# **Enter employee details**
# Name	1324.0

# %%
display_name_type(name)
# Out:
# 1324.0 <class 'str'>

# %% [markdown]
# > Make a class for Employee and print it ?

# %% [markdown]
# > How call by ref works in python

# %%
name, age, city = 'F', 22, 'Kottayam'

print(age,name,city)
# Out:
# 22 F Kottayam

# %%
# x,y,z = 23 , TypeError: cannot unpack non-iterable int object
# Instead
x = y = z = 25
y
# Out:
# 25

# %% [markdown]
# *Explicit and implicit type cast*

# %%
a = "a"
b = 9.0

c = a + b
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-1e29f9a9f81a> in <module>
#       2 b = 9.0
#       3
# ----> 4 c = a + b
#       5 c
#
# TypeError: can only concatenate str (not "float") to str

# %%
int(-8.8)
# Out:
# -8

# %% [markdown]
# > Floor and ceil in python ?

# %%
from math import floor, ceil
print(floor(5.5))
print(ceil(5.5))

# %%
# another way for writing QUOTIENT or FLOOR
print(5//2)
# Out:
# 5
# 6

# %% [markdown]
# > Upload an image from local to the notebook using PIL ?

# %%
display_name_type(False+True)
# Out:
# 1 <class 'int'>

# %%
display_name_type(1 + 10j)
# Out:
# (1+10j) <class 'complex'>

# %%
str(10.0)
# Out:
# '10.0'

# %%
int(100)
# Out:
# 100

# %% [markdown]
# *Observtions*
# - base in int gives considers different number systems
# - lists are not accepted

# %%
# List of keywords
from keyword import kwlist

print(kwlist)
print('Total keywords',len(kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Total keywords 35

# %%
int(50.0 + int('10'))
# Out:
# 60

# %% [markdown]
# > Types of error in python and when to expect?

# %% [markdown]
# Examples
# - Type Error
# - Value
# - Syntax
# - Indentation

# %% [markdown]
# ## Operators  in python

# %% [markdown]
# ### Logical operators

# %% [markdown]
# Addition, Subtraction, Multiply, division, modulus in numerical and string,

# %%
var = "Great learning\n" * 10
var
# Out:
# 'Great learning\nGreat learning\nGreat learning\nGreat learning\nGreat learning\nGreat learning\nGreat learning\nGreat learning\nGreat learning\nGreat learning\n'

# %% [markdown]
# > Putting '\n' in joined string

# %%
print(var)
# Out:
# Great learning
# Great learning
# Great learning
# Great learning
# Great learning
# Great learning
# Great learning
# Great learning
# Great learning
# Great learning

# %% [markdown]
# **'//' Floor or Quotient operator**
#
# **'%' Modulo or Remainder operator**
#
# **'\*\*' For power**

# %%
num = 10

print(num**2, num**3)
# Out:
# 100 1000

# %% [markdown]
# **If the numerator is less than denominato then the value is truncated**

# %%
2//10
# Out:
# 0

# %%
2 % 10
# Out:
# 2

# %% [markdown]
# ### Runtime variable

# %%
test = input("Check if its a num\t:")
# Out:
# Check if its a num	:-10

# %%
"This is alphabet or numeric " + str(test.isalnum())
# Out:
# 'This is alphabet or numeric False'

# %%
"This is alphabet " + str(test.isalpha())
# Out:
# 'This is alphabet False'

# %%
"This is digit " + str(test.isdigit())
# Out:
# 'This is digit False'

# %%
a = int(input("in1"))
# float not allowed in these
b = int(input("in2"))
# Out:
# in111.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-cbc5dcf1bf75> in <module>
# ----> 1 a = int(input("in1"))
#       2 # float not allowed in these
#       3 b = int(input("in2"))
#
# ValueError: invalid literal for int() with base 10: '11.0'

# %%
'-11'.isdigit()
# Out:
# False

# %%
'-11.0'.isdigit()
# Out:
# False

# %% [markdown]
# **Observations**
# - Negative considered as non digit

# %% [markdown]
# ## Relational operator
#
# <, >, ==, !=,

# %%
a = True
b = 0

a == b
# Out:
# False

# %% [markdown]
# ## Logical operator
#
# ```
# AND, OR, NOT
# ```

# %% [markdown]
# > How XOR is represented?

# %%
a = 20
gender = 'M'

# %%
a > 2 and gender == 'M'
# Out:
# True

# %%
a > 2 && gender == 'M'
# Out:
#   File "<ipython-input-128-709eef6891a7>", line 1
#     if a > 2 && gender == 'M':
#               ^
# SyntaxError: invalid syntax

# %%
a > 2 or gender == 'M'
# Out:
# True

# %% [markdown]
# ### Assignment operator

# %%
=, +=, %=

# %% [markdown]
# ### String operations

# %%
lst = ['This', 'is', 'fun']
lst.reverse()
",".join(lst)
# Out:
# 'fun,is,This'

# %%
# F strings

f'this is {lst}'
# Out:
# "this is ['fun', 'is', 'This']"

# %%
# format string

"f name is {}".format(lst)
# Out:
# "f name is ['fun', 'is', 'This']"

# %%
"f name is %s"%(lst)

# %s string
# %d int
# %f float
# Out:
# "f name is ['fun', 'is', 'This']"

# %%
"Precision can be controlled by %.2f"% 1.22345
# Out:
# 'Precision can be controlled by 1.22'

# %%
# len

name = "Thisisit"
len(name)
# Out:
# 9

# %%
# replace

name.replace('i', "I",1)
# Out:
# 'ThIsisit '

# %%
# upper, lower, 


# rstrip, strip, lstrip

# %%
# title, only the first one capital

name.title()
# Out:
# 'Thisisit '

# %%
"name          d".split()
# Out:
# ['name', 'd']

# %%
name
# Out:
# 'Thisisit '

# %% [markdown]
# ## Data Slicing

# %%
name
# Out:
# 'Thisisit '

# %%
# Reversing
name[::-1]
# Out:
# ' tisisihT'

# %%
name = "Test text"
name
# Out:
# 'Test text'

# %%
# start index, end index, increment 
print(name[8:0:-1])
print(name[::-1])

print('\n'+name[8::-1])
# Out:
# txet tse
# txet tseT
#
# txet tseT
