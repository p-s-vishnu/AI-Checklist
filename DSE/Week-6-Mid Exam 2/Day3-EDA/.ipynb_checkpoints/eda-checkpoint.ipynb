# %% [markdown]
# # <center>EDA</center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Literacy survey

# %%
ls
# Out:
#  Volume in drive D is DATA
#  Volume Serial Number is 7EF8-6C7E
#
#  Directory of D:\Github\AI-Checklist\DSE\Week-6-Mid Exam 2\Day3-EDA
#
# 25-09-2019  12:24    <DIR>          .
# 25-09-2019  12:24    <DIR>          ..
# 25-09-2019  11:58    <DIR>          .ipynb_checkpoints
# 25-09-2019  11:57            55,628 insurance.csv
# 25-09-2019  12:24               989 Untitled.ipynb
#                2 File(s)         56,617 bytes
#                3 Dir(s)  895,848,951,808 bytes free

# %%
df = pd.read_csv('./insurance.csv')

df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
def age_cat(x):
    if x <= 23:
        return 1
    elif x <= 39:
        return 2
    elif x <= 59:
        return 3
    else:
        return 4

# %%
age_d = {
    1:"18-23",
    2:"24-39",
    3:"40-59",
    4:"60+"
}
age_d
# Out:
# {1: '18-23', 2: '24-39', 3: '40-59', 4: '60+'}

# %%
    df['age_cat'] = df['age'].apply(age_cat)

# %% [markdown]
# ### Bi variate analysis

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'age_cat'],
#       dtype='object')

# %%
sns.FacetGrid(df,hue="region",height=5)\
    .map(sns.barplot,'sex',"charges")\
    .add_legend()

# %%
cat_cols = df.select_dtypes(include="object").columns
cat_cols
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %% [markdown]
# Age v/s charges

# %%
sns.scatterplot(data=df, x='age',y='charges',hue='smoker')

# %%
df['children'].describe()
# Out:
# count    1338.000000
# mean        1.094918
# std         1.205493
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %%
# sns.barplot(data=df,x="children",y="charges")
df.groupby(by="children")['charges'].agg('mean')
# Out:
# children
# 0    12365.975602
# 1    12731.171832
# 2    15073.563734
# 3    15355.318367
# 4    13850.656311
# 5     8786.035247
# Name: charges, dtype: float64

# %%
df.groupby(by="children")['charges'].agg('mean').plot.bar()
plt.show()

# %%
sns.scatterplot(data=df, x='age',y='charges',hue='sex')

# %%
sns.scatterplot(data=df, x='age',y='charges',hue='region')

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
pd.crosstab(df['sex'],df['smoker'])
# Out:
# smoker   no  yes
# sex
# female  547  115
# male    517  159

# %%
pd.crosstab(df['sex'],df['smoker'],normalize=0).plot.bar(stacked=True)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'age_cat'],
#       dtype='object')

# %%
sns.swarmplot(data=df, x='sex',y='charges')

# %%
sns.relplot(data=df, x='sex',y='charge')
